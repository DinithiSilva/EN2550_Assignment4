# %%
# %matplotlib inline
# %load_ext tensorboard
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets,layers, models
import numpy as np
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()       #load data

K = len(np.unique(y_train))     # Number of classes
# Normalize pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)
x_train = x_train - mean_image
x_test = x_test - mean_image
y_train = tf.keras.utils.to_categorical(y_train, num_classes=K)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#Create a sequential model
model = models.Sequential()
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape=(32,32,3)))        # 32, 3X3 convolution layers
model.add(layers.MaxPooling2D((2,2)))                                               # 2x2 max pooling layer
model.add(layers.Conv2D(64,(3,3), activation='relu' ))                              # 64, 3X3 convolution layers
model.add(layers.MaxPooling2D((2,2)))                                               # 2x2 max pooling layer
model.add(layers.Conv2D(64,(3,3), activation='relu' ))                              # 64, 3X3 convolution layers
model.add(layers.MaxPooling2D((2,2)))                                               # 2x2 max pooling layer
model.add(layers.Flatten())                                                         # Flattening the output of the convolutional layer
model.add(layers.Dense(64, activation='relu' ))                                     # fully connected layer with 64 units
model.add(layers.Dense(10))                                                         # fully connected layer with 10 units

model.summary()     #Get model summary
SGD=tf.keras.optimizers.SGD(learning_rate=0.01, decay=0.999, momentum =0.9, name='SGD', nesterov= False) #Get SGD optimizer with momentum
model.compile(optimizer=SGD, loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics=['accuracy']) 

history = model.fit(x_train, y_train, epochs=50, batch_size=50, validation_data=(x_test, y_test))

print(model.optimizer.get_config())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2976 - accuracy: 0.1082 - val_loss: 2.2944 - val_accuracy: 0.1108
# Epoch 2/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2943 - accuracy: 0.1172 - val_loss: 2.2936 - val_accuracy: 0.1124
# Epoch 3/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 2.2943 - accuracy: 0.1168 - val_loss: 2.2932 - val_accuracy: 0.1128
# Epoch 4/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 2.2941 - accuracy: 0.1170 - val_loss: 2.2929 - val_accuracy: 0.1139
# Epoch 5/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2932 - accuracy: 0.1200 - val_loss: 2.2926 - val_accuracy: 0.1143
# Epoch 6/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2928 - accuracy: 0.1213 - val_loss: 2.2924 - val_accuracy: 0.1155
# Epoch 7/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2930 - accuracy: 0.1187 - val_loss: 2.2922 - val_accuracy: 0.1163
# Epoch 8/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2929 - accuracy: 0.1191 - val_loss: 2.2921 - val_accuracy: 0.1168
# Epoch 9/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2927 - accuracy: 0.1206 - val_loss: 2.2919 - val_accuracy: 0.1168
# Epoch 10/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2928 - accuracy: 0.1185 - val_loss: 2.2918 - val_accuracy: 0.1170
# Epoch 11/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2926 - accuracy: 0.1180 - val_loss: 2.2917 - val_accuracy: 0.1173
# Epoch 12/50
# 1000/1000 [==============================] - 46s 46ms/step - loss: 2.2919 - accuracy: 0.1191 - val_loss: 2.2916 - val_accuracy: 0.1171
# Epoch 13/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2922 - accuracy: 0.1224 - val_loss: 2.2915 - val_accuracy: 0.1173
# Epoch 14/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2920 - accuracy: 0.1222 - val_loss: 2.2914 - val_accuracy: 0.1175
# Epoch 15/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2919 - accuracy: 0.1212 - val_loss: 2.2914 - val_accuracy: 0.1177
# Epoch 16/50
# 1000/1000 [==============================] - 46s 46ms/step - loss: 2.2923 - accuracy: 0.1182 - val_loss: 2.2913 - val_accuracy: 0.1179
# Epoch 17/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 2.2919 - accuracy: 0.1196 - val_loss: 2.2912 - val_accuracy: 0.1180
# Epoch 18/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 2.2920 - accuracy: 0.1209 - val_loss: 2.2912 - val_accuracy: 0.1181
# Epoch 19/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2918 - accuracy: 0.1230 - val_loss: 2.2911 - val_accuracy: 0.1182
# Epoch 20/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2915 - accuracy: 0.1209 - val_loss: 2.2910 - val_accuracy: 0.1184
# Epoch 21/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 2.2918 - accuracy: 0.1212 - val_loss: 2.2910 - val_accuracy: 0.1183
# Epoch 22/50
# 1000/1000 [==============================] - 49s 49ms/step - loss: 2.2910 - accuracy: 0.1235 - val_loss: 2.2909 - val_accuracy: 0.1185
# Epoch 23/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2914 - accuracy: 0.1230 - val_loss: 2.2909 - val_accuracy: 0.1187
# Epoch 24/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2916 - accuracy: 0.1210 - val_loss: 2.2908 - val_accuracy: 0.1190
# Epoch 25/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2914 - accuracy: 0.1208 - val_loss: 2.2908 - val_accuracy: 0.1192
# Epoch 26/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2911 - accuracy: 0.1251 - val_loss: 2.2908 - val_accuracy: 0.1192
# Epoch 27/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2910 - accuracy: 0.1226 - val_loss: 2.2907 - val_accuracy: 0.1194
# Epoch 28/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2915 - accuracy: 0.1178 - val_loss: 2.2907 - val_accuracy: 0.1196
# Epoch 29/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2913 - accuracy: 0.1188 - val_loss: 2.2906 - val_accuracy: 0.1195
# Epoch 30/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2913 - accuracy: 0.1230 - val_loss: 2.2906 - val_accuracy: 0.1196
# Epoch 31/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2914 - accuracy: 0.1201 - val_loss: 2.2906 - val_accuracy: 0.1197
# Epoch 32/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2910 - accuracy: 0.1222 - val_loss: 2.2905 - val_accuracy: 0.1197
# Epoch 33/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2913 - accuracy: 0.1213 - val_loss: 2.2905 - val_accuracy: 0.1201
# Epoch 34/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2908 - accuracy: 0.1223 - val_loss: 2.2905 - val_accuracy: 0.1202
# Epoch 35/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2909 - accuracy: 0.1214 - val_loss: 2.2904 - val_accuracy: 0.1202
# Epoch 36/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2910 - accuracy: 0.1240 - val_loss: 2.2904 - val_accuracy: 0.1205
# Epoch 37/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2911 - accuracy: 0.1217 - val_loss: 2.2904 - val_accuracy: 0.1206
# Epoch 38/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2913 - accuracy: 0.1211 - val_loss: 2.2904 - val_accuracy: 0.1209
# Epoch 39/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2911 - accuracy: 0.1222 - val_loss: 2.2903 - val_accuracy: 0.1208
# Epoch 40/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2912 - accuracy: 0.1231 - val_loss: 2.2903 - val_accuracy: 0.1207
# Epoch 41/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2910 - accuracy: 0.1234 - val_loss: 2.2903 - val_accuracy: 0.1208
# Epoch 42/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2907 - accuracy: 0.1212 - val_loss: 2.2903 - val_accuracy: 0.1208
# Epoch 43/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2907 - accuracy: 0.1237 - val_loss: 2.2902 - val_accuracy: 0.1208
# Epoch 44/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2912 - accuracy: 0.1212 - val_loss: 2.2902 - val_accuracy: 0.1208
# Epoch 45/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2908 - accuracy: 0.1245 - val_loss: 2.2902 - val_accuracy: 0.1209
# Epoch 46/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2904 - accuracy: 0.1246 - val_loss: 2.2902 - val_accuracy: 0.1209
# Epoch 47/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2908 - accuracy: 0.1230 - val_loss: 2.2902 - val_accuracy: 0.1207
# Epoch 48/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 2.2909 - accuracy: 0.1224 - val_loss: 2.2901 - val_accuracy: 0.1207
# Epoch 49/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2910 - accuracy: 0.1200 - val_loss: 2.2901 - val_accuracy: 0.1208
# Epoch 50/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 2.2908 - accuracy: 0.1213 - val_loss: 2.2901 - val_accuracy: 0.1208
# {'name': 'SGD', 'learning_rate': 0.01, 'decay': 0.999, 'momentum': 0.9, 'nesterov': False}

# %%
history_lists=[history.history['loss'],history.history['val_loss'],history.history['accuracy'],history.history['val_accuracy']]
titles=['train_loss','testing_loss','training_accuracy','testing_accuracy']
fig,ax=plt.subplots(1,4,figsize=(25,5))
for i in range(len(history_lists)):
        ax[i].plot(history_lists[i])
        ax[i].set_title(titles[i])
        ax[i].set_xlabel("epoch")
        ax[i].plot()
